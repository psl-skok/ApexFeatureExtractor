# %%
import pandas as pd
from pathlib import Path
from typing import Dict, List, Union
from pydantic import BaseModel
from openai import OpenAI
import os
from dotenv import load_dotenv
import json

# Load environment variables
load_dotenv()

# Initialize OpenAI client with API key from environment
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# # Original Altice Data Sample

# %%
# Load the CSV file
df = pd.read_csv("FullCallDataSummary.csv").head(10)

# Display the data as a table
df
# Out:
#   NaturalId                                       Conversation
# 0     Call1  [Agent] "Thank you for choosing Optimum Busine...
# 1    Call10  [Agent] "Thank you for choosing Optimum Busine...
# 2   Call100  [Agent] "Good morning. Thank you for calling O...
# 3   Call101  [Agent] "Good morning. Thank you for calling O...
# 4   Call102  [Agent] "Hold on one second, hold on, do not d...
# 5   Call103  [Agent] "Thank you for calling Optimum. No off...
# 6   Call104  [Agent] "Thank you for calling Optimum Busines...
# 7   Call105  [Agent] "Thank you for calling O Business. Thi...
# 8   Call106  [Agent] "Thank you for calling Optimum Busines...
# 9   Call107  [Agent] "For calling Optimum for Business now ...

# %% [markdown]
# # Categorical Classification Function

# %%
# Define ClassificationResult model
class ClassificationResult(BaseModel):
    classification: str
    explanation: str

def classify_call_transcripts(
    classifications: List[str],
    dataframe: pd.DataFrame,
    context_prompt: str,
    transcript_column: str,
    classification_column: str = "Classification",
    explanation_column: str = "Explanation"
) -> pd.DataFrame:
    """
    Classify call transcripts using LLM analysis.
    
    Args:
        classifications (List[str]): List of possible classifications (including "None")
        dataframe (pd.DataFrame): DataFrame with call data
        context_prompt (str): Context/question for classification
        transcript_column (str): Name of the column containing transcript text
        classification_column (str): Name for the output classification column
        explanation_column (str): Name for the output explanation column
    
    Returns:
        pd.DataFrame: Original DataFrame with added classification columns
    """
    
    # Initialize results list
    results: List[ClassificationResult] = []
    
    # Create classifications string for the prompt
    classifications_str = ", ".join(classifications)
    
    # Define the system prompt
    system_prompt = f"""
    You are an expert at analyzing sales call transcripts for classification purposes.
    
    Your task: {context_prompt}
    
    Available classifications: {classifications_str}
    
    For each conversation transcript, you must:
    1. Select exactly ONE classification from the provided list
    2. Provide a comprehensive explanation that includes:
        - Key customer statements or behaviors that influenced your decision
        - Any commitments, objections, or next steps mentioned
        - Your reasoning for why this classification best fits the conversation
    
    Return your response as a JSON object with this exact format:
    {{
        "classification": "selected_classification_from_list",
        "explanation": "One sentence explaining why you chose this classification"
    }}
    
    Important: The classification must be exactly one of the provided options: {classifications_str}
    """
    
    print(f"Processing {len(dataframe)} conversations...")
    
    # Process each conversation
    for idx, row in dataframe.iterrows():
        call_id = str(row.iloc[0])  # First column is call ID
        transcript_text = row[transcript_column]  # Use the specified column name
        
        if pd.isna(transcript_text):
            # Handle missing transcript
            results.append(ClassificationResult(
                explanation="No transcript text available for analysis",
                classification="None"
            ))
            continue
            
        try:
            # Create the user prompt with the conversation
            user_prompt = f"""
            Call ID: {call_id}
            
            Transcript:-
            {transcript_text}
            
            Analyze this transcript and return the JSON with your classification and explanation.
            """
            
            # Make the API call using structured output
            response = client.chat.completions.create(
                model="gpt-4o-mini",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt}
                ],
                temperature=0,
                max_tokens=300,
                response_format={"type": "json_object"}
            )
            
            # Parse the response
            response_text = response.choices[0].message.content.strip()
            
            # Parse JSON and create ClassificationResult
            import json
            parsed_response = json.loads(response_text)
            result = ClassificationResult(
                explanation=parsed_response["explanation"],
                classification=parsed_response["classification"]
            )
            results.append(result)
                
        except Exception as e:
            print(f"Error processing call {call_id}: {str(e)}")
            results.append(ClassificationResult(
                explanation=f"Error during processing: {str(e)}",
                classification="None"
            ))
        
        # Progress indicator
        if (idx + 1) % 10 == 0:
            print(f"Processed {idx + 1}/{len(dataframe)} conversations...")
    
    print("Classification complete!")

    # Convert results list to DataFrame
    results_df = pd.DataFrame([result.model_dump() for result in results])
    
    # Merge with original dataframe using variable column names
    merged_df = dataframe.copy()
    merged_df[classification_column] = results_df['classification']
    merged_df[explanation_column] = results_df['explanation']
    
    return merged_df

# %% [markdown]
# # Use Categorical Classification to Identify Call Outcome Stage

# %%
# Define the classifications list
classifications = [
    "Closed Sale",
    "Strong Lead",
    "Moderate Lead",
    "Weak Lead",
    "Not a Lead", 
    "Insufficient Data"
]

# Define the context prompt
context_prompt = """Analyze this sales call transcript and classify it into one of the following sales process stages based on the customer's level of engagement, interest, and the outcome of the conversation:

1. **Closed Sale** - Customer commits to purchasing/signing up during this call
2. **Strong Lead** - High intent, decision maker, budget available, urgent need/timeline
3. **Moderate Lead** - Moderate intent, needs identified, budget constraints or longer timeline
4. **Weak Lead** - Low intent, unclear needs, budget/authority concerns
5. **Not a Lead** - Customer explicitly declines, no budget/authority, or not viable
6. **Insufficient Data** - Call incomplete or customer interest unclear


Consider the following factors when classifying:
- Customer's explicit statements about interest level
- Whether any commitment or agreement was made
- Customer's tone and engagement level
- Specific next steps mentioned
- Whether the customer requested follow-up information or meetings
- Any objections raised and how they were addressed

Focus on the customer's behavior and statements rather than the salesperson's actions. A call should only be classified as "Definitive Sale on the Call" if there is clear evidence of a commitment or agreement made during this specific conversation."""

#Run classify_call_transcripts
results_with_sales_stage = classify_call_transcripts(classifications, df, context_prompt, "Conversation", "stage")
results_with_sales_stage
# Out:
# Processing 10 conversations...
# Processed 10/10 conversations...
# Classification complete!
#   NaturalId                                       Conversation          stage  \
# 0     Call1  [Agent] "Thank you for choosing Optimum Busine...  Moderate Lead
# 1    Call10  [Agent] "Thank you for choosing Optimum Busine...    Strong Lead
# 2   Call100  [Agent] "Good morning. Thank you for calling O...  Moderate Lead
# 3   Call101  [Agent] "Good morning. Thank you for calling O...    Closed Sale
# 4   Call102  [Agent] "Hold on one second, hold on, do not d...    Closed Sale
# 5   Call103  [Agent] "Thank you for calling Optimum. No off...    Closed Sale
# 6   Call104  [Agent] "Thank you for calling Optimum Busines...    Closed Sale
# 7   Call105  [Agent] "Thank you for calling O Business. Thi...    Strong Lead
# 8   Call106  [Agent] "Thank you for calling Optimum Busines...    Closed Sale
# 9   Call107  [Agent] "For calling Optimum for Business now ...    Closed Sale
#
#                                          Explanation
# 0  The customer expressed a clear interest in set...
# 1  The customer expressed a clear need for system...
# 2  The customer expressed interest in porting the...
# 3  The customer committed to installing the inter...
# 4  The customer, Rosa, explicitly committed to se...
# 5  The customer confirmed their order for service...
# 6  The customer committed to upgrading their serv...
# 7  The customer, Ali, demonstrates high intent to...
# 8  The customer explicitly committed to the servi...
# 9  The customer committed to the service installa...

# %%
# Usage Example: Optimized Category Extractor with Parallel Processing
# This demonstrates the improved performance and functionality

# Example usage with parallel processing
extracted_categories_optimized = category_extractor_optimized(
    dataframe=df,
    transcript_column="Conversation", 
    context_prompt="Extract names of products offered by Optimum telecommunications to business customers mentioned in the conversations between Optimum Business sales agents and customers. Exclude competitor mentions and non-Optimum related products",
    max_workers=8  # Process 8 transcripts in parallel
)

# View results
print(f"Found {extracted_categories_optimized.total_categories} products:")
for category in extracted_categories_optimized.categories:
    print(f"- {category.categoryName}: {category.categoryDefinition}")

# Performance comparison note:
# The optimized version processes transcripts in parallel, significantly reducing processing time
# for large datasets while maintaining the same accuracy and functionality.

# %% [markdown]
# # Category Extractor without category definitions

# %%
# Category Name Extractor Function (No Definitions)
from typing import Dict, List, Union
from pydantic import BaseModel
from concurrent.futures import ThreadPoolExecutor
import json

class CategoryName(BaseModel):
    categoryName: str

class CategoryNameExtractionResult(BaseModel):
    categories: List[CategoryName]
    total_categories: int

def category_name_extractor(
    dataframe: pd.DataFrame,
    transcript_column: str,
    context_prompt: str,
    target_column: str = "Category_Extraction",
    max_workers: int = 8
) -> CategoryNameExtractionResult:
    """
    Extract category names from transcripts through open-ended generation with parallel processing.
    Processes transcripts in parallel and generates 1-10 category names per call (no definitions).
    
    Args:
        dataframe: DataFrame with transcript data
        transcript_column: Name of the column containing transcript text
        context_prompt: Context/question for category extraction
        target_column: Column name for storing extraction results (used internally)
        max_workers: Maximum number of parallel workers (default: 8)
    
    Returns:
        CategoryNameExtractionResult: Object containing all extracted category names
    """
    print(f"Starting category name extraction for {len(dataframe)} transcripts...")
    print(f"Context: {context_prompt}")
    
    # Store all unique category names
    all_categories = set()  # Set to automatically handle duplicates
    
    # Process transcripts in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        futures = [
            executor.submit(
                _extract_category_names_from_transcript,
                str(row[transcript_column]),
                context_prompt,
                idx + 1
            )
            for idx, row in dataframe.iterrows()
        ]
        
        # Collect results as they complete
        for i, future in enumerate(futures):
            try:
                transcript_categories = future.result()
                
                # Add to master collection
                for category_name in transcript_categories:
                    all_categories.add(category_name)
                
                # Progress indicator (every 10 completions)
                if (i + 1) % 10 == 0:
                    print(f"Processed {i + 1}/{len(dataframe)} transcripts...")
                    
            except Exception as e:
                print(f"Error processing transcript {i + 1}: {str(e)}")
    
    # Convert to result object
    categories_list = [
        CategoryName(categoryName=name)
        for name in sorted(all_categories)  # Sort for consistent output
    ]
    
    result = CategoryNameExtractionResult(
        categories=categories_list,
        total_categories=len(categories_list)
    )
    
    print(f"\nCategory name extraction complete!")
    print(f"Total unique category names found: {len(categories_list)}")
    
    # Print all category names
    print("\nExtracted Category Names:")
    for i, category in enumerate(categories_list, 1):
        print(f"{i}. {category.categoryName}")
    
    return result

def _extract_category_names_from_transcript(
    transcript_text: str, 
    context_prompt: str, 
    transcript_idx: int
) -> List[str]:
    """Extract category names from a single transcript - names only version"""
    
    # Truncate transcript if too long
    processed_transcript = transcript_text[:8000] + "... [truncated]" if len(transcript_text) > 8000 else transcript_text
    
    system_prompt = f"""You are an expert at extracting category names from text.

Your task: {context_prompt}

You must:
1. Extract 1-10 distinct category names from the transcript
2. Provide exact names/identifiers (be precise, avoid duplicates)
3. Return only category names explicitly mentioned or clearly referenced in the transcript
4. Do NOT provide definitions or descriptions

Return your response as a JSON object with this exact format:
{{
    "categoryNames": [
        "Exact name or identifier",
        "Another category name",
        "Third category name"
    ]
}}"""

    user_prompt = f"""Extract category names from the following transcript based on the criteria provided.

Context: {context_prompt}

Transcript (ID: {transcript_idx}):
{processed_transcript}

Please extract all relevant category names following the instructions above. Return only the names, no definitions."""

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0,
            max_tokens=1500,  # Reduced since no definitions needed
            response_format={"type": "json_object"}
        )
        
        parsed_response = json.loads(response.choices[0].message.content.strip())
        
        # Extract category names
        category_names = [
            str(name) for name in parsed_response["categoryNames"]
        ]
        
        print(f"  Extracted {len(category_names)} category names: {category_names}")
        return category_names
        
    except Exception as e:
        print(f"  Error during category name extraction: {str(e)}")
        return []

# %% [markdown]
# Extractor w/o definitions usage

# %%
# Usage Example: Category Name Extractor (No Definitions)
# This demonstrates extracting only category names without definitions

# Example usage - extract only product names (no descriptions)
extracted_names = category_name_extractor(
    dataframe=df,
    transcript_column="Conversation", 
    context_prompt="Extract names of products offered by Optimum telecommunications to business customers mentioned in the conversations between Optimum Business sales agents and customers. Exclude competitor mentions and non-Optimum related products",
    max_workers=8  # Process 8 transcripts in parallel
)

# View results - only names, no definitions
print(f"Found {extracted_names.total_categories} unique product names:")
for category in extracted_names.categories:
    print(f"- {category.categoryName}")

# Benefits of this version:
# - Faster processing (no definitions to generate)
# - Lower token usage (reduced max_tokens)
# - Simpler output (just names)
# - Better for when you only need the category names
# Out:
# Starting category name extraction for 10 transcripts...
# Context: Extract names of products offered by Optimum telecommunications to business customers mentioned in the conversations between Optimum Business sales agents and customers. Exclude competitor mentions and non-Optimum related products
#   Extracted 4 category names: ['TV', 'internet', 'telephone', 'fiber']
#   Extracted 6 category names: ['internet service', 'mobile phones', 'tablets', 'point of sale', 'cameras', 'cash register']
#   Extracted 6 category names: ['fiber', 'X gigabit', 'X mega', 'X giga', 'product protection', 'emergency backup']
#   Extracted 7 category names: ['Optimum Business Class', 'Optimum Mobile', 'Wi Fi', 'gig service for business class', 'TV services', 'internet', 'mobile plan']
#   Extracted 7 category names: ['Optimum Mobile', 'internet service', 'phone number', 'gig speed of service', 'modem', 'router', 'wireless failover service']
#   Extracted 8 category names: ['Optimum Mobile', 'phone system', 'internet', 'modem', 'business features', 'caller ID', 'faster speed', 'connection backup']
#   Extracted 10 category names: ['cable', 'phone', 'Internet', 'high speed internet', 'cable boxes', 'phone lines', 'modem and router', 'secure network', 'support', 'backup']
#   Extracted 10 category names: ['Optimum Mobile', 'fiber', 'coax connection', 'phone line', 'fax line', 'modem rental', 'mobile service', 'unlimited mobile plans', 'static IP', 'business phone line']
#   Extracted 7 category names: ['Optimum Mobile', 'high speed internet', 'fiber', 'coax cable', '1 gig', 'multi-gig', 'POS system']
#   Extracted 6 category names: ['Optimum Mobile', 'internet', 'phone', 'fiber', 'unlimited phone', 'mobile service']
# Processed 10/10 transcripts...
#
# Category name extraction complete!
# Total unique category names found: 54
#
# Extracted Category Names:
# 1. 1 gig
# 2. Internet
# 3. Optimum Business Class
# 4. Optimum Mobile
# 5. POS system
# 6. TV
# 7. TV services
# 8. Wi Fi
# 9. X giga
# 10. X gigabit
# 11. X mega
# 12. backup
# 13. business features
# 14. business phone line
# 15. cable
# 16. cable boxes
# 17. caller ID
# 18. cameras
# 19. cash register
# 20. coax cable
# 21. coax connection
# 22. connection backup
# 23. emergency backup
# 24. faster speed
# 25. fax line
# 26. fiber
# 27. gig service for business class
# 28. gig speed of service
# 29. high speed internet
# 30. internet
# 31. internet service
# 32. mobile phones
# 33. mobile plan
# 34. mobile service
# 35. modem
# 36. modem and router
# 37. modem rental
# 38. multi-gig
# 39. phone
# 40. phone line
# 41. phone lines
# 42. phone number
# 43. phone system
# 44. point of sale
# 45. product protection
# 46. router
# 47. secure network
# 48. static IP
# 49. support
# 50. tablets
# 51. telephone
# 52. unlimited mobile plans
# 53. unlimited phone
# 54. wireless failover service
# Found 54 unique product names:
# - 1 gig
# - Internet
# - Optimum Business Class
# - Optimum Mobile
# - POS system
# - TV
# - TV services
# - Wi Fi
# - X giga
# - X gigabit
# - X mega
# - backup
# - business features
# - business phone line
# - cable
# - cable boxes
# - caller ID
# - cameras
# - cash register
# - coax cable
# - coax connection
# - connection backup
# - emergency backup
# - faster speed
# - fax line
# - fiber
# - gig service for business class
# - gig speed of service
# - high speed internet
# - internet
# - internet service
# - mobile phones
# - mobile plan
# - mobile service
# - modem
# - modem and router
# - modem rental
# - multi-gig
# - phone
# - phone line
# - phone lines
# - phone number
# - phone system
# - point of sale
# - product protection
# - router
# - secure network
# - static IP
# - support
# - tablets
# - telephone
# - unlimited mobile plans
# - unlimited phone
# - wireless failover service

# %% [markdown]
# # Category Extractor Function
#
# This notebook contains the Category Extractor function for extracting categories from transcript conversations through open-ended generation.

# %% [markdown]
# ## Function Overview
#
# The `category_extractor` function processes each transcript individually and generates 1-10 categories per call based on the provided context prompt. Unlike the MECE theme analysis, this function:
#
# - **No MECE constraints**: Categories don't need to be mutually exclusive
# - **Individual processing**: Goes through calls one by one (no batching)
# - **Open-ended extraction**: Focuses on comprehensive extraction based on prompts
# - **Returns categories only**: Only extracts categories with definitions, no classification
#
# **Example use cases:**
# - Extracting all product names mentioned
# - Identifying company names referenced
# - Finding technical terms used
# - Extracting software mentions

# %%
# Optimized Category Extractor Function with Parallel Processing
from typing import Dict, List, Union
from pydantic import BaseModel
from concurrent.futures import ThreadPoolExecutor
import json

class Category(BaseModel):
    categoryName: str
    categoryDefinition: str

class CategoryExtractionResult(BaseModel):
    categories: List[Category]
    total_categories: int

def category_extractor_optimized(
    dataframe: pd.DataFrame,
    transcript_column: str,
    context_prompt: str,
    target_column: str = "Category_Extraction",
    max_workers: int = 8
) -> CategoryExtractionResult:
    """
    Extract categories from transcripts through open-ended generation with parallel processing.
    Processes transcripts in parallel and generates 1-10 categories per call.
    
    Args:
        dataframe: DataFrame with transcript data
        transcript_column: Name of the column containing transcript text
        context_prompt: Context/question for category extraction
        target_column: Column name for storing extraction results (used internally)
        max_workers: Maximum number of parallel workers (default: 8)
    
    Returns:
        CategoryExtractionResult: Object containing all extracted categories
    """
    print(f"Starting category extraction for {len(dataframe)} transcripts...")
    print(f"Context: {context_prompt}")
    
    # Store all unique categories with their definitions
    all_categories = {}  # category_name -> category_definition
    
    # Process transcripts in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        futures = [
            executor.submit(
                _extract_categories_from_transcript_optimized,
                str(row[transcript_column]),
                context_prompt,
                idx + 1
            )
            for idx, row in dataframe.iterrows()
        ]
        
        # Collect results as they complete
        for i, future in enumerate(futures):
            try:
                transcript_categories = future.result()
                
                # Add to master collection
                for category in transcript_categories:
                    category_name = category.categoryName
                    if category_name not in all_categories:
                        all_categories[category_name] = category.categoryDefinition
                    else:
                        # Use longer definition if available
                        existing_def = all_categories[category_name]
                        new_def = category.categoryDefinition
                        if len(new_def) > len(existing_def):
                            all_categories[category_name] = new_def
                
                # Progress indicator (every 10 completions)
                if (i + 1) % 10 == 0:
                    print(f"Processed {i + 1}/{len(dataframe)} transcripts...")
                    
            except Exception as e:
                print(f"Error processing transcript {i + 1}: {str(e)}")
    
    # Convert to result object
    categories_list = [
        Category(categoryName=name, categoryDefinition=definition)
        for name, definition in all_categories.items()
    ]
    
    result = CategoryExtractionResult(
        categories=categories_list,
        total_categories=len(categories_list)
    )
    
    print(f"\nCategory extraction complete!")
    print(f"Total unique categories found: {len(categories_list)}")
    
    # Print all categories
    print("\nExtracted Categories:")
    for i, category in enumerate(categories_list, 1):
        print(f"{i}. {category.categoryName}: {category.categoryDefinition}")
    
    return result

def _extract_categories_from_transcript_optimized(
    transcript_text: str, 
    context_prompt: str, 
    transcript_idx: int
) -> List[Category]:
    """Extract categories from a single transcript - optimized version"""
    
    # Truncate transcript if too long
    processed_transcript = transcript_text[:8000] + "... [truncated]" if len(transcript_text) > 8000 else transcript_text
    
    system_prompt = f"""You are an expert at extracting categories from text.

Your task: {context_prompt}

You must:
1. Extract 1-10 distinct categories from the transcript
2. Provide exact names/identifiers (be precise, avoid duplicates)
3. Include clear definitions for each category
4. Return only categories explicitly mentioned or clearly referenced in the transcript

Return your response as a JSON object with this exact format:
{{
    "categories": [
        {{
            "categoryName": "Exact name or identifier",
            "categoryDefinition": "Clear description of what this category represents"
        }}
    ]
}}"""

    user_prompt = f"""Extract categories from the following transcript based on the criteria provided.

Context: {context_prompt}

Transcript (ID: {transcript_idx}):
{processed_transcript}

Please extract all relevant categories following the instructions above."""

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0,
            max_tokens=2000,
            response_format={"type": "json_object"}
        )
        
        parsed_response = json.loads(response.choices[0].message.content.strip())
        
        # Create Category objects
        categories = [
            Category(
                categoryName=str(category["categoryName"]),
                categoryDefinition=str(category["categoryDefinition"])
            ) for category in parsed_response["categories"]
        ]
        
        print(f"  Extracted {len(categories)} categories: {[c.categoryName for c in categories]}")
        return categories
        
    except Exception as e:
        print(f"  Error during category extraction: {str(e)}")
        return []

# %% [markdown]
# # Usage Example: Extract Product Names

# %%
# Load your data
df = results_with_sales_stage
# Extract product names
extracted_categories = category_extractor(
    dataframe=df,
    transcript_column="Conversation", 
    context_prompt="Extract names of products offered by Optimum telecommunications to business customers mentioned in the conversations between Optimum Business sales agents and customers. Exclude competitor mentions and non-Optimum related products"
)

# View results
print(f"Found {extracted_categories.total_categories} products:")
for category in extracted_categories.categories:
    print(f"- {category.categoryName}: {category.categoryDefinition}")
# Out:
# Starting category extraction for 10 transcripts...
# Context: Extract names of products offered by Optimum telecommunications to business customers mentioned in the conversations between Optimum Business sales agents and customers. Exclude competitor mentions and non-Optimum related products
# Processing transcript 1/10...
#   Extracted 5 categories: ['Optimum Business Class', 'Optimum Mobile', 'Gig Service for Business Class', 'Wi-Fi Service', 'Static IP']
# Processing transcript 2/10...
#   Extracted 7 categories: ['Optimum Mobile', 'Internet Service', 'Phone System', 'Modem', 'Connection Backup', 'Business Features', 'Faster Speed Upgrade']
# Processing transcript 3/10...
#   Extracted 5 categories: ['Optimum Mobile', 'Fiber Internet', 'Business Phone Line', 'Secondary Line', 'Static IP']
# Processing transcript 4/10...
#   Extracted 5 categories: ['Internet Service', 'Telephone Service', 'Fiber Internet', 'Double Play', 'Free Installation']
# Processing transcript 5/10...
#   Extracted 8 categories: ['High Speed Internet', 'Phone Lines', 'Cable TV', 'Cable Boxes', 'Modem and Router', 'Support Services', 'Backup Internet Service', 'Automatic Bill Pay']
# Processing transcript 6/10...
#   Extracted 7 categories: ['Internet Service', 'Gig Speed Service', 'Phone Service', 'Rollover Phone Numbers', 'Modem', 'Router', 'Wireless Failover Service']
# Processing transcript 7/10...
#   Extracted 3 categories: ['X gig fiber', 'Product protection', 'Emergency backup']
# Processing transcript 8/10...
#   Extracted 3 categories: ['Internet Service', 'Mobile Phone Service', 'Bundled Services']
# Processing transcript 9/10...
#   Extracted 8 categories: ['Optimum Mobile', 'High Speed Internet', 'Fiber Internet', 'Gigabit Internet', 'POS System Support', 'No Contract Service', 'Equipment Provision', 'Money Back Guarantee']
# Processing transcript 10/10...
#   Extracted 4 categories: ['Optimum Mobile', 'Internet Service', 'Phone Service', 'Bundled Services']
#
# Category extraction complete!
# Total unique categories found: 40
#
# Extracted Categories:
# 1. Optimum Business Class: A service package offered by Optimum that includes various telecommunications solutions tailored for business customers.
# 2. Optimum Mobile: A mobile service plan offered by Optimum that includes unlimited talk and text, with options for bundling with business accounts.
# 3. Gig Service for Business Class: High-speed internet service offered by Optimum for business customers, providing gigabit speeds and including necessary equipment.
# 4. Wi-Fi Service: Wireless internet service provided by Optimum, suitable for businesses needing connectivity for multiple devices.
# 5. Static IP: A service option that provides a fixed IP address for businesses, useful for hosting servers or other applications requiring consistent connectivity.
# 6. Internet Service: High-speed internet service provided by Optimum, specifically fiber internet, offering various speeds for business customers.
# 7. Phone System: A telecommunication system that includes features like caller ID, offered by Optimum Business.
# 8. Modem: A device provided by Optimum Business that connects to the internet and supports business phone systems.
# 9. Connection Backup: A feature that ensures continuous internet service by automatically activating backup support during outages.
# 10. Business Features: Additional features offered by Optimum Business for phone services, such as caller ID and long-distance calling.
# 11. Faster Speed Upgrade: An upgrade option for internet service that provides higher bandwidth to accommodate more devices and improve performance.
# 12. Fiber Internet: A type of internet service that uses fiber-optic technology to provide high-speed internet access, noted for its reliability and speed.
# 13. Business Phone Line: A standard phone line service for business customers, allowing for communication needs.
# 14. Secondary Line: An additional phone line that can be added to an existing account, often used for specific purposes like faxing.
# 15. Telephone Service: Telecommunication service that includes multiple telephone lines for business use, allowing features such as call forwarding and porting of existing numbers.
# 16. Double Play: A bundled service offering that includes both internet and telephone services at a combined rate.
# 17. Free Installation: A promotional offer that waives installation fees for new service setups.
# 18. High Speed Internet: A broadband internet service provided by Optimum Business, designed to support multiple devices and high data usage.
# 19. Phone Lines: Telecommunication lines provided by Optimum for business use, allowing multiple simultaneous calls.
# 20. Cable TV: Television service that includes various channels and programming, specifically tailored for business customers.
# 21. Cable Boxes: Devices provided by Optimum to enable cable television service for business customers.
# 22. Modem and Router: Equipment provided by Optimum to facilitate internet connectivity for business customers.
# 23. Support Services: Technical support offered by Optimum for troubleshooting network issues, available to business customers.
# 24. Backup Internet Service: A service that ensures continuous internet access even during outages, provided by Optimum.
# 25. Automatic Bill Pay: A payment option that allows business customers to set up automatic payments for their services with Optimum.
# 26. Gig Speed Service: A high-speed internet service that allows businesses to handle multiple online transactions and services simultaneously.
# 27. Phone Service: Business phone service offered by Optimum, which includes unlimited calls within the US, Canada, and Puerto Rico.
# 28. Rollover Phone Numbers: A feature that allows incoming calls to be redirected to another phone number if the primary line is busy.
# 29. Router: A device that routes internet traffic within a business's local network, allowing multiple devices to connect to the internet.
# 30. Wireless Failover Service: A backup internet service that activates if the primary internet connection fails, ensuring continuous connectivity.
# 31. X gig fiber: A high-speed internet service offering X gigabit bandwidth, suitable for businesses requiring substantial data transfer capabilities.
# 32. Product protection: A service that provides coverage for equipment and ensures that business operations remain uninterrupted in case of equipment failure.
# 33. Emergency backup: A backup device that activates when the primary internet connection fails, ensuring that critical business operations continue without interruption.
# 34. Mobile Phone Service: Telecommunication services providing mobile phone lines for business use, including options for tablets.
# 35. Bundled Services: A combination of internet and phone services offered at a discounted rate when subscribed together.
# 36. Gigabit Internet: An internet service that provides speeds of up to 1 gigabit per second, suitable for businesses with high data demands.
# 37. POS System Support: Internet service that supports Point of Sale systems, ensuring reliable connectivity for business transactions.
# 38. No Contract Service: A service plan that allows customers to use Optimum's offerings on a month-to-month basis without a long-term commitment.
# 39. Equipment Provision: The provision of necessary equipment, such as routers and modems, to customers as part of the service package.
# 40. Money Back Guarantee: A customer satisfaction guarantee that allows customers to receive a refund if they are not satisfied with the service within a specified period.
# Found 40 products:
# - Optimum Business Class: A service package offered by Optimum that includes various telecommunications solutions tailored for business customers.
# - Optimum Mobile: A mobile service plan offered by Optimum that includes unlimited talk and text, with options for bundling with business accounts.
# - Gig Service for Business Class: High-speed internet service offered by Optimum for business customers, providing gigabit speeds and including necessary equipment.
# - Wi-Fi Service: Wireless internet service provided by Optimum, suitable for businesses needing connectivity for multiple devices.
# - Static IP: A service option that provides a fixed IP address for businesses, useful for hosting servers or other applications requiring consistent connectivity.
# - Internet Service: High-speed internet service provided by Optimum, specifically fiber internet, offering various speeds for business customers.
# - Phone System: A telecommunication system that includes features like caller ID, offered by Optimum Business.
# - Modem: A device provided by Optimum Business that connects to the internet and supports business phone systems.
# - Connection Backup: A feature that ensures continuous internet service by automatically activating backup support during outages.
# - Business Features: Additional features offered by Optimum Business for phone services, such as caller ID and long-distance calling.
# - Faster Speed Upgrade: An upgrade option for internet service that provides higher bandwidth to accommodate more devices and improve performance.
# - Fiber Internet: A type of internet service that uses fiber-optic technology to provide high-speed internet access, noted for its reliability and speed.
# - Business Phone Line: A standard phone line service for business customers, allowing for communication needs.
# - Secondary Line: An additional phone line that can be added to an existing account, often used for specific purposes like faxing.
# - Telephone Service: Telecommunication service that includes multiple telephone lines for business use, allowing features such as call forwarding and porting of existing numbers.
# - Double Play: A bundled service offering that includes both internet and telephone services at a combined rate.
# - Free Installation: A promotional offer that waives installation fees for new service setups.
# - High Speed Internet: A broadband internet service provided by Optimum Business, designed to support multiple devices and high data usage.
# - Phone Lines: Telecommunication lines provided by Optimum for business use, allowing multiple simultaneous calls.
# - Cable TV: Television service that includes various channels and programming, specifically tailored for business customers.
# - Cable Boxes: Devices provided by Optimum to enable cable television service for business customers.
# - Modem and Router: Equipment provided by Optimum to facilitate internet connectivity for business customers.
# - Support Services: Technical support offered by Optimum for troubleshooting network issues, available to business customers.
# - Backup Internet Service: A service that ensures continuous internet access even during outages, provided by Optimum.
# - Automatic Bill Pay: A payment option that allows business customers to set up automatic payments for their services with Optimum.
# - Gig Speed Service: A high-speed internet service that allows businesses to handle multiple online transactions and services simultaneously.
# - Phone Service: Business phone service offered by Optimum, which includes unlimited calls within the US, Canada, and Puerto Rico.
# - Rollover Phone Numbers: A feature that allows incoming calls to be redirected to another phone number if the primary line is busy.
# - Router: A device that routes internet traffic within a business's local network, allowing multiple devices to connect to the internet.
# - Wireless Failover Service: A backup internet service that activates if the primary internet connection fails, ensuring continuous connectivity.
# - X gig fiber: A high-speed internet service offering X gigabit bandwidth, suitable for businesses requiring substantial data transfer capabilities.
# - Product protection: A service that provides coverage for equipment and ensures that business operations remain uninterrupted in case of equipment failure.
# - Emergency backup: A backup device that activates when the primary internet connection fails, ensuring that critical business operations continue without interruption.
# - Mobile Phone Service: Telecommunication services providing mobile phone lines for business use, including options for tablets.
# - Bundled Services: A combination of internet and phone services offered at a discounted rate when subscribed together.
# - Gigabit Internet: An internet service that provides speeds of up to 1 gigabit per second, suitable for businesses with high data demands.
# - POS System Support: Internet service that supports Point of Sale systems, ensuring reliable connectivity for business transactions.
# - No Contract Service: A service plan that allows customers to use Optimum's offerings on a month-to-month basis without a long-term commitment.
# - Equipment Provision: The provision of necessary equipment, such as routers and modems, to customers as part of the service package.
# - Money Back Guarantee: A customer satisfaction guarantee that allows customers to receive a refund if they are not satisfied with the service within a specified period.

# %%
import pandas as pd

# Create a new DataFrame with two columns: 'categoryName' and 'categoryDefinition'
categories_df = pd.DataFrame(
    [(cat.categoryName, cat.categoryDefinition) for cat in extracted_categories.categories],
    columns=["categoryName", "categoryDefinition"]
)

# Display the new DataFrame
display(categories_df)
# Out:
#                       categoryName  \
# 0           Optimum Business Class
# 1                   Optimum Mobile
# 2   Gig Service for Business Class
# 3                    Wi-Fi Service
# 4                        Static IP
# 5                 Internet Service
# 6                     Phone System
# 7                            Modem
# 8                Connection Backup
# 9                Business Features
# 10            Faster Speed Upgrade
# 11                  Fiber Internet
# 12             Business Phone Line
# 13               Telephone Service
# 14                     Double Play
# 15               Free Installation
# 16             High Speed Internet
# 17                     Phone Lines
# 18                        Cable TV
# 19                     Cable Boxes
# 20                Modem and Router
# 21                Support Services
# 22         Backup Internet Service
# 23              Automatic Bill Pay
# 24               Gig Speed Service
# 25                   Phone Service
# 26          Rollover Phone Numbers
# 27                          Router
# 28       Wireless Failover Service
# 29                     X gig fiber
# 30              Product protection
# 31         Emergency backup device
# 32                Gigabit Internet
# 33            Mobile Phone Service
# 34                     Tablet Line
# 35              POS System Support
# 36             No Contract Service
# 37            Money Back Guarantee
# 38                Bundled Services
#
#                                    categoryDefinition
# 0   A service package offered by Optimum that incl...
# 1   A mobile service plan offered by Optimum that ...
# 2   High-speed internet service offered by Optimum...
# 3   Wireless internet service provided by Optimum ...
# 4   A service option that provides a fixed IP addr...
# 5   High-speed internet service provided by Optimu...
# 6   A telecommunication system that includes featu...
# 7   A device provided by Optimum Business that con...
# 8   A feature that automatically activates to main...
# 9   Additional features offered by Optimum Busines...
# 10  An upgrade option for internet service that pr...
# 11  A type of internet service that uses fiber-opt...
# 12  A standard phone line service for business cus...
# 13  Telecommunication service that includes multip...
# 14  A bundled service offering that includes both ...
# 15  A promotional offer that waives installation f...
# 16  A broadband internet service provided by Optim...
# 17  Telecommunication lines provided by Optimum fo...
# 18  Television service that includes various chann...
# 19  Devices provided by Optimum that allow busines...
# 20  Equipment provided by Optimum to enable intern...
# 21  Technical assistance offered by Optimum for tr...
# 22  A service that ensures continuous internet acc...
# 23  A payment option that allows customers to set ...
# 24  A high-speed internet service that supports mu...
# 25  Telecommunication services that include the pr...
# 26  A feature that allows incoming calls to be red...
# 27  A device that routes internet traffic within a...
# 28  A backup internet service that activates if th...
# 29  A high-speed internet service offering X gigab...
# 30  A service that provides coverage for equipment...
# 31  A device that activates to maintain internet c...
# 32  An internet service that provides speeds of up...
# 33  Telecommunication service that provides mobile...
# 34  Service that offers mobile data plans for tabl...
# 35  Internet services that support Point of Sale s...
# 36  A service plan that allows customers to use Op...
# 37  A customer satisfaction guarantee that allows ...
# 38  A combination of internet and phone services o...

# %%
categories_df.to_csv("extracted_categories.csv", index=False)

# %% [markdown]
# ## Notes
#
# 1. **OpenAI API Key Required**: Make sure your `.env` file contains `OPENAI_API_KEY=your_key_here`
# 2. **Rate Limits**: The function processes transcripts individually, which may take time for large datasets
# 3. **Token Limits**: Long transcripts are automatically truncated to ~2000 tokens for processing
# 4. **Category Deduplication**: Duplicate categories are automatically merged, keeping the longer definition
# 5. **Error Handling**: Failed transcript processing is logged and continues with the next transcript
